# %%
from datachain import DataChain

# %%
# Initialize DataChain for your local image folder
chain = DataChain.from_storage('s3://ff-ai-data/DVC-Sample-Dataset/', object_name='image')

# # Optionally, filter images (e.g., only JPEGs)
# chain = chain.filter(lambda file: file.name.endswith('.jpg'))

# # Save metadata to a Parquet file
# chain.save('dataset.parquet')

# %%
chain = chain.filter(lambda file: file.name.endswith('.jpg'))

# %%
chain.save('dataset.parquet')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 chain.save('dataset.parquet')
#
# File /media/static/Smruti/AI-Tasks/venv-python_310/lib/python3.10/site-packages/datachain/lib/dc.py:767, in DataChain.save(self, name, version, **kwargs)
#     758 """Save to a Dataset. It returns the chain itself.
#     759
#     760 Parameters:
#    (...)
#     763     version : version of a dataset. Default - the last version that exist.
#     764 """
#     765 schema = self.signals_schema.clone_without_sys_signals().serialize()
#     766 return self._evolve(
# --> 767     query=self._query.save(
#     768         name=name, version=version, feature_schema=schema, **kwargs
#     769     )
#     770 )
#
# ...
